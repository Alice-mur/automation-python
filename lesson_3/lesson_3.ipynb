# %% [markdown]
# # Python

# %% [markdown]
# ## Идентификаторы

# %%
print(42)
print(42.5)
print("42")
print(True)
print("False")
# Out:
# 42
# 42.5
# 42
# True
# False

# %% [markdown]
# 1. Скобки (parentheses)
# 2. Возведение в степень (Exponentiation)
# 3. Умножение(Multiplication)
# 4. Деление (Division)
# 5. Сложение (Addition)
# 6. Вычитаниее (Substraction)
